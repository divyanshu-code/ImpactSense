# %% [markdown]
# ### Streamlit
# `streamlit` is an open-source Python framework designed to help data scientists and AI/ML engineers quickly build and share interactive web applications with very few lines of code. It enables creation of dynamic data apps, dashboards, and user interfaces without requiring expertise in front-end technologies like HTML, CSS, or JavaScript.
#
# - Definition:
# `streamlit` lets you transform Python scripts into interactive web apps rapidly. This makes it ideal for building dashboards, reports, machine learning model demos, and data visualization tools in a simple and Pythonic way. By running the Python script with Streamlit, it launches a local web server and renders the app in a browser, allowing live interaction and instant feedback.
#
# - Key Features:
#   - Simple and Pythonic: Write apps with pure Python code using an intuitive API.
#
#   - Fast Prototyping: Build interactive data apps in minutes rather than weeks.
#
#   - Live Editing: Apps update instantly as you modify the script.
#
#   - Widgets for Interaction: Includes buttons, sliders, text input, file uploaders, and more to capture user input.
#
#   - Rich Media Support: Supports text, markdown, code, LaTeX, images, audio, and video display.
#
#   - Layout Options: Columns, sidebar, expanders for flexible user interface design.
#
#   - State Management: Maintains widget and app state across user interactions.
#
#   - Animations and Feedback: Progress bars, spinners, and balloons to enhance user experience.
#
#   - Data Visualization: Easily integrate charts and dataframes.
#
#   - Open Source and Extensible: Active community with many add-ons and integrations.
#
#   - Deployment Options: Can be deployed locally, on cloud platforms, or enterprise solutions like Streamlit Cloud or Snowflake.
#
# These features make Streamlit a popular choice for quickly transforming Python data scripts into professional interactive applications with minimal effort.

# %% [markdown]
# #### 1. Title, Header, Subheader, and Text

# %%
import streamlit as st           # Import streamlit library
st.title('This is a Title')
st.header('This is a Header')
st.subheader('This is a Subheader')
st.text('This is a standard text message.')
# Out:
# 2025-11-28 19:55:54.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# These are used to add textual headings and plain text to the app.
#
# - `title` displays the largest heading.
#
# - `header` is slightly smaller.
#
# - `subheader` is smaller than header but larger than normal text.
#
# - `text` displays simple unformatted text.

# %% [markdown]
# #### 2. Markdown, Code, LaTeX, and Write

# %%
st.markdown('# Markdown Title\nSome **bold** and _italic_ text.')
st.code('print("Hello, Streamlit!")', language='python')
st.latex('e^{i\\pi} + 1 = 0')
st.write('Write can display various data types including text, numbers, and dataframes')
# Out:
# 2025-11-28 19:55:54.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `markdown` allows rich-formatted text using Markdown syntax. Here it shows a big header and inline formatting like bold and italics.
#
# - `code` displays syntax-highlighted code blocks. The language param helps to highlight Python keywords.
#
# - `latex` renders mathematical formulas using LaTeX syntax.
#
# - `write` is a flexible shortcut that can display many object types: strings, numbers, lists, dataframes, plots, etc.

# %% [markdown]
# #### 3. Interactive Widgets Section
#
# This block demonstrates various input widgets that capture user interactions.

# %%
if st.button('Click me'):
    st.write('Button clicked!')
# Out:
# 2025-11-28 19:55:54.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `button`: a clickable button that triggers an action when clicked.

# %%
if st.checkbox('Check me'):
    st.write('Checkbox is checked')
# Out:
# 2025-11-28 19:55:54.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `checkbox`: toggles between checked/unchecked states, useful for boolean choice.

# %%
choice = st.radio('Choose one:', ['Option 1', 'Option 2'])
st.write(f'You chose {choice}')
# Out:
# 2025-11-28 19:55:54.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.461 Session state does not function when running a script without `streamlit run`
# 2025-11-28 19:55:54.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `radio`: presents exclusive options where user selects one.

# %%
option = st.selectbox('Select:', ['A', 'B', 'C'])
st.write(f'Selected {option}')
# Out:
# 2025-11-28 19:55:54.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `selectbox`: dropdown for selecting a single value.

# %%
options = st.multiselect('Select multiple:', ['A', 'B', 'C'])
st.write(f'Selected {options}')
# Out:
# 2025-11-28 19:55:54.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `multiselect`: dropdown for selecting multiple values.

# %%
val = st.slider('Slide me', 0, 100, 25)
st.write(f'Slider value {val}')
# Out:
# 2025-11-28 19:55:54.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `slider`: numeric input with a draggable slider. Here range is 0-100 with default 25.

# %%
text = st.text_input('Enter text:')
st.write(f'Your input: {text}')
# Out:
# 2025-11-28 19:55:54.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `text_input`: single line text from user.

# %%
num = st.number_input('Enter a number:', 0, 100)
st.write(f'Number: {num}')
# Out:
# 2025-11-28 19:55:54.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:54.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `number_input`: numeric input with specified range.

# %%
date = st.date_input('Pick a date')
st.write(f'Date selected: {date}')
# Out:
# 2025-11-28 19:55:55.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `date_input`: calendar date picker.

# %%
time_val = st.time_input('Pick a time')
st.write(f'Time selected: {time_val}')
# Out:
# 2025-11-28 19:55:55.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - `time_input`: time picker widget.

# %% [markdown]
# #### 4. File and Media Inputs

# %%
file = st.file_uploader('Upload file')
if file:
    st.write(f'Filename: {file.name}')
# Out:
# 2025-11-28 19:55:55.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - Let users upload files from their systems.
# - Files can be further processed if uploaded.

# %%
img = st.camera_input('Take a picture')
if img:
    st.image(img)
# Out:
# 2025-11-28 19:55:55.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - Access webcam to take pictures, then display them.

# %%
color = st.color_picker('Pick a color')
st.write(f'Color: {color}')
# Out:
# 2025-11-28 19:55:55.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - Displays color picker wheel to choose a color; returns hex color code.

# %% [markdown]
# #### 5. Layout & Animation

# %%
col1, col2 = st.columns(2)
col1.write('Column 1')
col2.write('Column 2')
# Out:
# 2025-11-28 19:55:55.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - Splits content horizontally into two columns for better layout.

# %%
with st.expander('Expand me'):
    st.write('Hidden text here')
# Out:
# 2025-11-28 19:55:55.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - Creates a collapsible section that hides contents until expanded.

# %%
with st.sidebar:
    st.write('Sidebar content here')
# Out:
# 2025-11-28 19:55:55.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - Adds elements inside a sidebar panel that is separate from main page.

# %%
st.balloons()
# Out:
# 2025-11-28 19:55:55.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# - Celebratory balloon animation, typically for success indication.

# %%
import time
with st.spinner('Loading...'):
    time.sleep(2)
st.write('Done!')
# Out:
# 2025-11-28 19:55:55.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:55.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:56.111 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:56.116 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:56.118 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - Shows a loading spinner for blocking operations to improve UX.

# %%
progress = st.progress(0)
for i in range(100):
    progress.progress(i + 1)
st.write('Progress complete')
# Out:
# 2025-11-28 19:55:57.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:57.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - Progress bar that can be updated dynamically.

# %%
st.metric(label='Temperature', value='70 °F', delta='-5 °F')
# Out:
# 2025-11-28 19:55:58.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:58.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 19:55:58.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# - Shows a metric with a main value and an optional delta indicating change from a previous number.
